# %%
import org.troy.capstone.entities.Item;
import org.troy.capstone.utils.TableUtils;
import tech.tablesaw.api.Table;
import tech.tablesaw.api.StringColumn;
import java.util.Collections;

Table table = TableUtils.readCleanedData();

// Add photoAuthor column (this one may not exist yet)
table.addColumns( StringColumn.create("photoAuthor", Collections.nCopies(table.rowCount(), "Kalen Emsley")) );

StringColumn authorUrl = StringColumn.create("photoAuthorUrl", Collections.nCopies(table.rowCount(),
    "https://unsplash.com/@kalenemsley?utm_source=sse554_capstone&utm_medium=referral"));
table.addColumns(authorUrl);

table.write().csv("C:\\Users\\thkle\\SSE554\\SSE554-Capstone-Project\\data\\1000_items_catalog_v2_cleaned.csv");
