# %%
import java.util.List;
import tech.tablesaw.api.Table;
import org.troy.capstone.constants.tableColumns;
import org.troy.capstone.utils.TableUtils;

Table table = TableUtils.readCleanedData();
//Print length of cost and lengfth of unique costs
System.out.println("Total number of items: " + table.rowCount());
List<Float> prices = table.floatColumn(tableColumns.PRICE.getColumnName()).unique().asList();
System.out.println("Number of unique prices: " + prices.size());
# Out:
# Total number of items: 1000
# Number of unique prices: 994
