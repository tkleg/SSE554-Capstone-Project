# %%
import java.util.List;
import tech.tablesaw.api.Table;
import org.troy.capstone.constants.TableColumnName;
import org.troy.capstone.constants.DataPath;
import org.troy.capstone.utils.TableUtils;

Table table = TableUtils.readData(DataPath.CLEANED_ATTRIBUTED_DATA);
//Print length of cost and lengfth of unique costs
System.out.println("Total number of items: " + table.rowCount());
List<Float> prices = table.floatColumn(TableColumnName.PRICE.getColumnName()).unique().asList();
System.out.println("Number of unique prices: " + prices.size());
# Out:
# Total number of items: 961
# Number of unique prices: 961
