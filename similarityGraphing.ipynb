# %%
import numpy as np

data = []
with open("similarity_analysis_output.dat", "r") as file:
    for line in file:
        data.append(float(line.strip()))

data = np.array(data)

import matplotlib.pyplot as plt

n_bins = 25
counts, bins, patches = plt.hist(data, bins=n_bins, edgecolor='black')
for b in bins:
    plt.axvline(b, color='red', linestyle='--', linewidth=0.7)
    plt.text(b, plt.ylim()[1]*0.98, f'{b:.2f}', rotation=90, va='top', ha='right', fontsize=8, color='red')
plt.ylabel('Frequency')
plt.xlabel('Similarity Score')
plt.title('Histogram of Similarity Scores')
plt.show()

# %%
percentile = 90
threshold = np.percentile(data, percentile)
print(f"{percentile}th percentile similarity score: {threshold}")
number_of_entries_above_threshold = np.size(data[data >= threshold])
print(f"Number of entries above {percentile}th percentile: {number_of_entries_above_threshold}")
# Out:
# 90th percentile similarity score: 3.7162029800000007
# Number of entries above 90th percentile: 46128
